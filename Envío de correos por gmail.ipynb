# %% [markdown]
# IMPORTANDO LIBRERÍAS

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase

# %% [markdown]
# CREDENCIALES DE REMITENTE Y DESTINATARIO

# %%
email_user = 'emaro03@gmail.com'
email_password = ''
email_send = 'emaro03@gmail.com', 'emanuel.almonte@hotmail.com'

# %% [markdown]
# CUERPO DEL CORREO

# %%
msg = MIMEMultipart()
msg['From'] = email_user
msg['To'] = ",".join(email_send)
msg['Subject'] = 'Prueba de envío de correos (ENNOVA)'

#body = '''Buenos días Sr. Castillo,\n\nEsperando se encuentre bien, una vez acordado la delimitación del scope para el proyecto de comunicación remota, a continuación, le facilito los detalles de los costos pertinentes.\n\nRespecto a la oferta facilitada y entendiendo las condiciones actuales de recesión económica producto del covid-19 es lo más inteligente ponderar las inversiones, sin embargo, la solución del proyecto en cuestión brinda a su disposición una herramienta útil con criterios ingenieriles de calidad para mejorar la operativa de unidad de energía.\n\nEn ese sentido, anexo se puede apreciar la propuesta con las modificaciones a los fines correspondientes y el ajuste en monto financiero.\n\nEsperando cumplir las expectativas e inicial nuestro modelo de negocio a la mayor brevedad posible.\n\n\nSaludos,'''
body = '''<p>Buenos d&iacute;as Sr. Castillo,</p>
<p>Esperando se encuentre bien, una vez acordado la delimitaci&oacute;n del scope para el proyecto de comunicaci&oacute;n remota, a continuaci&oacute;n, le facilito los detalles de los costos pertinentes.</p>
<p>Respecto a la oferta facilitada y entendiendo las condiciones actuales de recesi&oacute;n econ&oacute;mica producto del covid-19 es lo m&aacute;s inteligente ponderar las inversiones, sin embargo, la soluci&oacute;n del proyecto en cuesti&oacute;n brinda a su disposici&oacute;n una herramienta &uacute;til con criterios ingenieriles de calidad para mejorar la operativa de unidad de energ&iacute;a.</p>
<p>En ese sentido, anexo se puede apreciar la propuesta con las modificaciones a los fines correspondientes y el ajuste en monto financiero.</p>
<p>Esperando cumplir las expectativas e inicial nuestro modelo de negocio a la mayor brevedad posible.</p>
<p>Saludos,</p>
<p><br></p>
<table  data-mysignature-date="2020-06-18T21:22:43.134Z" data-mysignature-is-paid="0" width="500" cellspacing="0" cellpadding="0" border="0"> <tr> <td> <table cellspacing="0" cellpadding="0" border="0"> <tr>  <td valign="top" width="100" style="padding:0 8px 0 0;vertical-align: top;"> <a target="_blank" href="https://mysignature.io/?utm_source&#x3D;logo"><img alt="created with MySignature.io" width="100" style="width:100px;moz-border-radius:10%;khtml-border-radius:10%;o-border-radius:10%;webkit-border-radius:10%;ms-border-radius:10%;border-radius:10%;" src="https://img.mysignature.io/p/4/1/f/41fd8b44-db98-5826-855b-8ed21b28f589.png?time=1592515056" /></a> </td>  <td style="font-size:1em;padding:0 15px 0 8px;vertical-align: top;" valign="top"> <table cellspacing="0" cellpadding="0" border="0" style="line-height: 1.4;font-family:Verdana, Geneva, sans-serif;font-size:90%;color: #000001;"> <tr> <td> <div style="font: 1.2em Verdana, Geneva, sans-serif;color:#000001;">Emanuel Almonte R.</div> </td> </tr> <tr> <td style="padding: 4px 0;"> <div style="color:#000001;font-family:Verdana, Geneva, sans-serif;"> Encargado de Proyecto  |  Vsmart  |  Ingeniería </div> </td> </tr>   <tr> <td> <span style="font-family:Verdana, Geneva, sans-serif;color:#91AE6D;">mobile:&nbsp;</span> <span><a style="font-family:Verdana, Geneva, sans-serif;color:#000001;" href="tel:+1 829 292-6370">+1 829 292-6370</a></span> </td> </tr>    <tr> <td> <span style="font-family:Verdana, Geneva, sans-serif;color:#91AE6D;">email:&nbsp;</span> <span><a href="mailto:emaro03@gmail.com" target="_blank" style="font-family:Verdana, Geneva, sans-serif;color: #000001;">emaro03@gmail.com</a></span> </td> </tr>     </table> </td>  <td style="border-left:3px solid;vertical-align:middle;padding:0 0 3px 6px;font-family: Arial;border-color:#91AE6D;" valign="middle"> <table cellspacing="0" cellpadding="0" border="0" style="line-height: 1;"> <tr><td style="padding: 4px 0 0 0;"><a target="_blank" class="social_link" href="https://www.linkedin.com/in/emaro03/"><img alt="created with MySignature.io" style="width:22px;" width="22" src="https://img.mysignature.io/s/v3/0/d/a/0da47aae-d980-5ecc-919d-f6cbbc5bd6e2.png"></a></td></tr><tr><td style="padding: 4px 0 0 0;"><a target="_blank" class="social_link" href="https://join.skype.com/invite/Ao5Ul3B00hzm"><img alt="created with MySignature.io" style="width:22px;" width="22" src="https://img.mysignature.io/s/v3/c/9/4/c94eed39-09e0-5aa6-819c-d0b528fe2465.png"></a></td></tr><tr><td style="padding: 4px 0 0 0;"><a target="_blank" class="social_link" href="https://github.com/emaro03"><img alt="created with MySignature.io" style="width:22px;" width="22" src="https://img.mysignature.io/s/v3/6/5/e/65e549fa-07e1-5c8e-8f2a-556ffaccb0d7.png"></a></td></tr><tr><td style="padding: 4px 0 0 0;"><a target="_blank" class="social_link" href="https://wa.me/18292926370"><img alt="created with MySignature.io" style="width:22px;" width="22" src="https://img.mysignature.io/s/v3/c/7/e/c7eb3596-ce17-5fe1-8c78-f7e7323981ac.png"></a></td></tr> </table> </td>  </tr> </table> </td> </tr></table><table width="500" cellspacing="0" cellpadding="0" border="0"> <tr> <td class="s_pixel" colspan="2"> <a href="https://mysignature.io/editor/?utm_source=freepixel"><img src="https://img.mysignature.io/pixel/925174/signature/162350"></a> </td> </tr> <tr> <td style="line-height: 1px;"></td> </tr></table><table class="branding" cellspacing="0" cellpadding="0" border="0"> <tr><td style="display:block;padding:15px 0 0 0;"></td></tr> <tr> <td style="border-top: 1px solid #eeeeee;padding-top: 5px;font-size:10px;font-family: Arial;"> <a href="https://mysignature.io?utm_source&#x3D;promotion&amp;utm_medium&#x3D;signature&amp;utm_campaign&#x3D;create_own_signature" style="color: #000001; text-decoration: none" target="_blank">Create your own <span style="color:#8ab366;">signature</span></a> </td> </tr></table>'''
msg.attach(MIMEText(body,'html'))

# %% [markdown]
# ADJUNTANDO ARCHIVO

# %%
part = MIMEBase('application','octet-stream')
part.set_payload((open(r'C:\Users\Owner\Desktop\6179FB50.xlsx','rb')).read())
encoders.encode_base64(part)
part.add_header('Content-Disposition',"attachment; filename= "+filename)
msg.attach(part)

# %% [markdown]
# ABRIR Y CERRAR SERVICIO SMTP

# %%
mail = smtplib.SMTP('smtp.gmail.com',587)
mail.starttls()
mail.login(email_user,email_password)
mail.sendmail(email_user, email_send, msg.as_string())
mail.quit()
