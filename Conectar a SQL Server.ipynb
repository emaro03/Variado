# %%
import pyodbc
import numpy as np
import pandas as pd

# %%
server = 'DESKTOP-T30LP15'
database = 'CentroMedico'

conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server}; \
                       SERVER='+ server +'; \
                       DATABASE='+ database +';\
                       Trusted_Connection=yes;')

cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM CentroMedico.dbo.TurnoEstado')

# %%
usuarios = cursor.fetchall()
usuarios
# Out:
# [(0, 'Pendiente'), (1, 'Realizado'), (2, 'Cancelado')]

# %%
usuarios2 = np.array(usuarios)
usuarios2
# Out:
# array([['0', 'Pendiente'],
#        ['1', 'Realizado'],
#        ['2', 'Cancelado']], dtype='<U11')

# %%
df = pd.DataFrame(
    {
        'Status': usuarios2[:,1],
        'Turno': usuarios2[:,0]
    }
)

# %%
df
# Out:
#       Status Turno
# 0  Pendiente     0
# 1  Realizado     1
# 2  Cancelado     2
